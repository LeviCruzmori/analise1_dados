# %% [markdown]
# <a href="https://colab.research.google.com/github/LeviCruzmori/analise1_dados/blob/main/analise_1_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import a biblioteca pandas
import pandas as pd

# %%
df = pd.read_csv( "/content/drive/MyDrive/DIO/Cusro_Python_Pandas_Digital_Innovation-master/datasets/Gapminder.csv",sep=';')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#renomeando as colunas
df.rename(columns={"country":'pais',"continent":'continente',"year":'ano',"lifeExp":'expectativa de vida',"pop":'população total','gdpPercap':'PIB'})

# %%
df.head(5)

# %%
#total de linhas e colunas
df.shape
# Out:
# (3312, 6)

# %%
df.columns #retorna os nomes das colunas

# %%
df.columns #retorna os nomes das colunas

# %%
df.dtypes #retorna os tipos de dados da tabela
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df['continent']= df['continent'].astype('object')

# %%
df.dtypes
# Out:
# country              object
# continent    string[python]
# year                  int64
# lifeExp               int64
# pop                   int64
# gdpPercap             int64
# dtype: object

# %%
#alterando o tipo de dado da coluna LojaID
df['lifeExp']= df['lifeExp'].astype('int64')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952       28   8425333  779.445314
# 1  Afghanistan      Asia  1957       30   9240934  820.853030
# 2  Afghanistan      Asia  1962       31  10267083  853.100710
# 3  Afghanistan      Asia  1967       34  11537966  836.197138
# 4  Afghanistan      Asia  1972       36  13079460  739.981106

# %%
#retorna as ultimas linhas, ou a quatidade selecionada
df.tail()

# %%
#alterando o tipo de dado da coluna LojaID
df['gdpPercap']= df['gdpPercap'].astype('int64')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop  gdpPercap
# 0  Afghanistan      Asia  1952       28   8425333        779
# 1  Afghanistan      Asia  1957       30   9240934        820
# 2  Afghanistan      Asia  1962       31  10267083        853
# 3  Afghanistan      Asia  1967       34  11537966        836
# 4  Afghanistan      Asia  1972       36  13079460        739
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['lifeExp'].plot(kind='hist', bins=20, title='lifeExp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['pop'].plot(kind='hist', bins=20, title='pop')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
_df_26['year'].plot(kind='line', figsize=(8, 4), title='year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.describe() #retorna informações estatisticas do nosso conjunto de dados

# %%
#fazer filtros  no conjnto de dados
df['continent'].unique()

# %%
df.groupby('continent')['country'].nunique()

# %%
#idade minima de mortalidade por ano
df.groupby('year')['lifeExp'].min()

# %%
df.groupby('year')['lifeExp'].mean() #retorna a media por ano

# %%
df.groupby('year')['lifeExp'].max()#retorna a idade maxima por ano

# %%
df['gdpPercap'].mean() #retorna a media do PIB

# %%
df['gdpPercap'].sum()
# Out:
# 37480660

# %%
df.groupby('country')['pop'].min()
# Out:
# country
# Afghanistan            8425333
# Albania                1282697
# Algeria                9279525
# Angola                 4232095
# Argentina             17876956
#                         ...
# Vietnam               26246839
# West Bank and Gaza     1030585
# Yemen, Rep.            4963829
# Zambia                 2672000
# Zimbabwe               3080907
# Name: pop, Length: 187, dtype: int64

# %%
#pegando uma amostra
df.sample()
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 543  Canada       NaN  1993    77.83  28920644  26590.39937

# %%
#consultando linhas com valores faltantes
df.isnull().sum()
# Out:
# country        0
# continent    301
# year           0
# lifeExp        0
# pop            0
# gdpPercap      0
# dtype: int64

# %%
df['lifeExp'].min()#retornando a idade minima
# Out:
# 23

# %%
df['lifeExp'].max()# retornando a idade max
# Out:
# 82

# %%
df['lifeExp'].mean()#retornando a idade media
# Out:
# 64.74396135265701

# %%
df.nlargest(3,'lifeExp')#seleciona as 3 linhas com a maior idade
# Out:
#                country continent  year  lifeExp        pop  gdpPercap
# 1284  Hong Kong, China      <NA>  2007       82    6980412      39724
# 1593             Japan      Asia  2002       82  127065841      28604
# 1594             Japan      Asia  2003       82  127214499      29073

# %%
df.nsmallest(3,'lifeExp')#retona as 3 linhas com a menor idade
# Out:
#           country continent  year  lifeExp      pop  gdpPercap
# 2519       Rwanda    Africa  1992       23  7290203        737
# 0     Afghanistan      Asia  1952       28  8425333        779
# 1     Afghanistan      Asia  1957       30  9240934        820

# %%
# ordenando o conjunto de dados, e emprimendo as 10 maiores receitas
df.sort_values('country', ascending=False).head(10)
# Out:
#        country continent  year  lifeExp       pop  gdpPercap
# 3311  Zimbabwe    Africa  2007       43  12311143        469
# 3305  Zimbabwe    Africa  1977       57   6642107        685
# 3300  Zimbabwe    Africa  1952       48   3080907        406
# 3301  Zimbabwe    Africa  1957       50   3646340        518
# 3302  Zimbabwe    Africa  1962       52   4277736        527
# 3304  Zimbabwe    Africa  1972       55   5861135        799
# 3303  Zimbabwe    Africa  1967       53   4995432        569
# 3306  Zimbabwe    Africa  1982       60   7636524        788
# 3307  Zimbabwe    Africa  1987       62   9216418        706
# 3308  Zimbabwe    Africa  1992       60  10704340        693
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
_df_5.plot(kind='scatter', x='lifeExp', y='pop', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#agrupamento por ano
df.groupby('country')['lifeExp'].sum()
# Out:
# country
# Afghanistan           443
# Albania               815
# Algeria               703
# Angola                447
# Argentina             823
#                      ...
# Vietnam               683
# West Bank and Gaza    719
# Yemen, Rep.           555
# Zambia                548
# Zimbabwe              625
# Name: lifeExp, Length: 187, dtype: int64
